# %%
import pandas as pd

# %%
news=pd.read_csv('C:/Users/tejas/My Projects/Stock News Sentiment Analysis Webapp/data/Zerodha_News_live.csv')
news
# Out:
#                                                  title  \
# 0    Gold edges up to Rs 88,790 per 10 g, silver dr...
# 1    Issue of AIFs circumventing regulations resolv...
# 2    Noida Airport Delay To Cost Tata Projects Rs 3...
# 3    HDFC Securities pays Rs 65 lakh to Sebi to set...
# 4    Student recruitment solution provider Crizac g...
# ..                                                 ...
# 206  Market Trading Guide: JK Cement, United Spirit...
# 207  Stock markets slump on U.S., China economic fears
# 208  Anupam Rasayan Signs LoA Worth Rs 922 Crore Wi...
# 209  Indians Lost Rs 107 Crore To Digital Payment F...
# 210  Zomato Shareholders Approve Renaming Company T...
#
#                                            description            date  \
# 0    Snapping its three-day losing run, gold reboun...  19 minutes ago
# 1    Sebi's whole-time member Ananth Narayan G on T...  22 minutes ago
# 2    Although the runway and control tower are comp...  26 minutes ago
# ...

# %%
news.isnull().sum()
# Out:
# title           0
# description    19
# date            0
# source          0
# url             0
# dtype: int64

# %%
news.fillna({'description':"No description available"}, inplace=True)
news
# Out:
#                                                  title  \
# 0    Gold edges up to Rs 88,790 per 10 g, silver dr...
# 1    Issue of AIFs circumventing regulations resolv...
# 2    Noida Airport Delay To Cost Tata Projects Rs 3...
# 3    HDFC Securities pays Rs 65 lakh to Sebi to set...
# 4    Student recruitment solution provider Crizac g...
# ..                                                 ...
# 206  Market Trading Guide: JK Cement, United Spirit...
# 207  Stock markets slump on U.S., China economic fears
# 208  Anupam Rasayan Signs LoA Worth Rs 922 Crore Wi...
# 209  Indians Lost Rs 107 Crore To Digital Payment F...
# 210  Zomato Shareholders Approve Renaming Company T...
#
#                                            description            date  \
# 0    Snapping its three-day losing run, gold reboun...  19 minutes ago
# 1    Sebi's whole-time member Ananth Narayan G on T...  22 minutes ago
# 2    Although the runway and control tower are comp...  26 minutes ago
# ...

# %%
news.isnull().sum()
# Out:
# title          0
# description    0
# date           0
# source         0
# url            0
# dtype: int64

# %%
sentiment=pd.read_csv('C:/Users/tejas/My Projects/Stock News Sentiment Analysis Webapp/data/sentiment_results.csv')
sentiment
# Out:
#                                                  title  \
# 0    Gold edges up to Rs 88,790 per 10 g, silver dr...
# 1    Issue of AIFs circumventing regulations resolv...
# 2    Noida Airport Delay To Cost Tata Projects Rs 3...
# 3    HDFC Securities pays Rs 65 lakh to Sebi to set...
# 4    Student recruitment solution provider Crizac g...
# ..                                                 ...
# 206  Market Trading Guide: JK Cement, United Spirit...
# 207  Stock markets slump on U.S., China economic fears
# 208  Anupam Rasayan Signs LoA Worth Rs 922 Crore Wi...
# 209  Indians Lost Rs 107 Crore To Digital Payment F...
# 210  Zomato Shareholders Approve Renaming Company T...
#
#                                            description            date  \
# 0    Snapping its three-day losing run, gold reboun...  19 minutes ago
# 1    Sebi's whole-time member Ananth Narayan G on T...  22 minutes ago
# 2    Although the runway and control tower are comp...  26 minutes ago
# ...
